# %%
import pandas as pd

# %%
data = pd.read_excel("HiFlo-DAT_Merged_FINAL_24.8.21.xlsx")

# %%
print(data.head())
# Out:
#                                Column No.  \
# 0                                     NaN
# 1      Entry Header (EXPAND TO SEE ALL)\n
# 2  Entry Explanations (EXPAND TO SEE ALL)
# 3                                     NaN
# 4                                     NaN
#
#                                            1  \
# 0                        Database Management
# 1                         Flood Event Number
# 2  Unique Flood event (merged record number)
# 3                                          1
# 4                                          2
#
#                                                    2  \
# 0                                                NaN
# 1                             Contributing # Sources
# 2  #Source identifiers contributing to the flood ...
# 3                                                 1a
# 4                                                 1b
#
#                                                    3  \
# ...
